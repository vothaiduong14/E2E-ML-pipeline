# %%
import pandas as pd
import eda_utils as utils
from prep_data_utils import DataProcessor
import numpy as np
import matplotlib.pyplot as plt

# %%
data_df = pd.read_csv('data/raw/train.csv')
data_df.head(15)
# Out:
#     id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0    1    Male   44                1         28.0                   0
# 1    2    Male   76                1          3.0                   0
# 2    3    Male   47                1         28.0                   0
# 3    4    Male   21                1         11.0                   1
# 4    5  Female   29                1         41.0                   1
# 5    6  Female   24                1         33.0                   0
# 6    7    Male   23                1         11.0                   0
# 7    8  Female   56                1         28.0                   0
# 8    9  Female   24                1          3.0                   1
# 9   10  Female   32                1          6.0                   1
# 10  11  Female   47                1         35.0                   0
# 11  12  Female   24                1         50.0                   1
# 12  13  Female   41                1         15.0                   1
# 13  14    Male   76                1         28.0                   0
# 14  15    Male   71                1         28.0                   1
#
#    Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    > 2 Years            Yes         40454.0                  26.0      217
# 1     1-2 Year             No         33536.0                  26.0      183
# 2    > 2 Years            Yes         38294.0                  26.0       27
# 3     < 1 Year             No         28619.0                 152.0      203
# 4     < 1 Year             No         27496.0                 152.0       39
# 5     < 1 Year            Yes          2630.0                 160.0      176
# 6     < 1 Year            Yes         23367.0                 152.0      249
# 7     1-2 Year            Yes         32031.0                  26.0       72
# 8     < 1 Year             No         27619.0                 152.0       28
# 9     < 1 Year             No         28771.0                 152.0       80
# 10    1-2 Year            Yes         47576.0                 124.0       46
# 11    < 1 Year             No         48699.0                 152.0      289
# 12    1-2 Year             No         31409.0                  14.0      221
# 13    1-2 Year            Yes         36770.0                  13.0       15
# 14    1-2 Year             No         46818.0                  30.0       58
#
#     Response
# 0          1
# 1          0
# 2          1
# 3          0
# 4          0
# 5          0
# 6          0
# 7          1
# 8          0
# 9          0
# 10         1
# 11         0
# 12         0
# 13         0
# 14         0

# %%
utils.count_values(data_df, 'Response')
# Out:
#    Response   count  percentage
# 0         0  334399       87.74
# 1         1   46710       12.26

# %%
dataProcessor = prep.DataProcessor(data_df)
dataProcessor.process_data()
train_df, test_df = dataProcessor.split_train_test()

# %%
train_df['Vehicle_Age_gt_2_Years']
# Out:
# 220145    0
# 194704    0
# 203625    0
# 218048    1
# 230458    0
#          ..
# 283035    0
# 265328    0
# 199055    0
# 204315    0
# 202004    0
# Name: Vehicle_Age_gt_2_Years, Length: 304887, dtype: uint8

# %%
utils.count_nan(data_df)
# Out:
#                   column  count  percentage
# 0                     id      0         0.0
# 1                 Gender      0         0.0
# 2                    Age      0         0.0
# 3        Driving_License      0         0.0
# 4            Region_Code      0         0.0
# 5     Previously_Insured      0         0.0
# 6            Vehicle_Age      0         0.0
# 7         Vehicle_Damage      0         0.0
# 8         Annual_Premium      0         0.0
# 9   Policy_Sales_Channel      0         0.0
# 10               Vintage      0         0.0
# 11              Response      0         0.0

# %%
data_df.shape
# Out:
# (381109, 12)

# %%
# get only a fraction of data for training:
data_df = data_df.sample(frac=0.3, replace=False, random_state=42).reset_index(drop=True)
data_df.shape
# Out:
# (114333, 12)

# %%
utils.show_pairplot(data_df, highest_only = True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/duong/Desktop/GitFolder/E2E-ML-pipeline-with-data/model_dev/01_dataCollection_and_EDA.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/duong/Desktop/GitFolder/E2E-ML-pipeline-with-data/model_dev/01_dataCollection_and_EDA.ipynb#ch0000008?line=0'>1</a> utils.show_pairplot(data_df, highest_only = True)
#
# File ~/Desktop/GitFolder/E2E-ML-pipeline-with-data/model_dev/eda_utils.py:53, in show_pairplot(data, highest_only, thresold)
#      50 plt.figure()
#      52 if highest_only:
# ---> 53     sns.pairplot(data, hue='Response', palette='coolwarm',
#      54                  vars=high_corr.columns)
#      55 else:
#      56     sns.pairplot(data, hue='Response', palette='coolwarm')
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/seaborn/axisgrid.py:2154, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2152 # Add a legend
#    2153 if hue is not None:
# -> 2154     grid.add_legend()
#    2156 grid.tight_layout()
#    2158 return grid
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/seaborn/axisgrid.py:165, in Grid.add_legend(self, legend_data, title, label_order, adjust_subtitles, **kwargs)
#     162     adjust_legend_subtitles(figlegend)
#     164 # Draw the plot to set the bounding boxes correctly
# --> 165 _draw_figure(self._figure)
#     167 # Calculate and set the new width of the figure so the legend fits
#     168 legend_width = figlegend.get_window_extent().width / self._figure.dpi
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/seaborn/utils.py:95, in _draw_figure(fig)
#      93 """Force draw of a matplotlib figure, accounting for back-compat."""
#      94 # See https://github.com/matplotlib/matplotlib/issues/19197 for context
# ---> 95 fig.canvas.draw()
#      96 if fig.stale:
#      97     try:
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:436, in FigureCanvasAgg.draw(self)
#     432 # Acquire a lock on the shared font cache.
#     433 with RendererAgg.lock, \
#     434      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435       else nullcontext()):
# --> 436     self.figure.draw(self.renderer)
#     437     # A GUI class may be need to update a window using this draw, so
#     438     # don't forget to call the superclass.
#     439     super().draw()
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/matplotlib/figure.py:2837, in Figure.draw(self, renderer)
#    2834         # ValueError can occur when resizing a window.
#    2836 self.patch.draw(renderer)
# -> 2837 mimage._draw_list_compositing_images(
#    2838     renderer, self, artists, self.suppressComposite)
#    2840 for sfig in self.subfigs:
#    2841     sfig.draw(renderer)
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:3091, in _AxesBase.draw(self, renderer)
#    3088         a.draw(renderer)
#    3089     renderer.stop_rasterizing()
# -> 3091 mimage._draw_list_compositing_images(
#    3092     renderer, self, artists, self.figure.suppressComposite)
#    3094 renderer.close_group('axes')
#    3095 self.stale = False
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/matplotlib/collections.py:990, in _CollectionWithSizes.draw(self, renderer)
#     987 @artist.allow_rasterization
#     988 def draw(self, renderer):
#     989     self.set_sizes(self._sizes, self.figure.dpi)
# --> 990     super().draw(renderer)
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/matplotlib/collections.py:424, in Collection.draw(self, renderer)
#     420     renderer.draw_markers(
#     421         gc, paths[0], combined_transform.frozen(),
#     422         mpath.Path(offsets), transOffset, tuple(facecolors[0]))
#     423 else:
# --> 424     renderer.draw_path_collection(
#     425         gc, transform.frozen(), paths,
#     426         self.get_transforms(), offsets, transOffset,
#     427         self.get_facecolor(), self.get_edgecolor(),
#     428         self._linewidths, self._linestyles,
#     429         self._antialiaseds, self._urls,
#     430         self._offset_position)
#     432 gc.restore()
#     433 renderer.close_group(self.__class__.__name__)
#
# File ~/.cache/pypoetry/virtualenvs/cross-sell-Lx49ICDI-py3.8/lib/python3.8/site-packages/matplotlib/path.py:200, in Path.vertices(self)
#     192     self._simplify_threshold = mpl.rcParams['path.simplify_threshold']
#     193     self._should_simplify = (
#     194         self._simplify_threshold > 0 and
#     195         mpl.rcParams['path.simplify'] and
#     196         len(self._vertices) >= 128 and
#     197         (self._codes is None or np.all(self._codes <= Path.LINETO))
#     198     )
# --> 200 @property
#     201 def vertices(self):
#     202     """
#     203     The list of vertices in the `Path` as an Nx2 numpy array.
#     204     """
#     205     return self._vertices
#
# KeyboardInterrupt:

# %%
utils.show_heatmap(data_df)

# %%
data_df[['Age', 'Vintage', 'Annual_Premium']]
# Out:
#         Age  Vintage  Annual_Premium
# 0        21       72         20408.0
# 1        55      102         37498.0
# 2        41       90          2630.0
# 3        26      268          2630.0
# 4        51      265         34006.0
# ...     ...      ...             ...
# 114328   24      166         63100.0
# 114329   30      161          2630.0
# 114330   41      170          2630.0
# 114331   29      272         49693.0
# 114332   44       77         36945.0
#
# [114333 rows x 3 columns]

# %%
processor = DataProcessor(data_df)
processed_df = processor.process_data()
train_df, test_df = processor.split_train_test()

# %%
train_df
# Out:
#        Gender       Age  Driving_License  Previously_Insured  Annual_Premium  \
# 82374       0  0.169231                1                   0        0.000000
# 81394       1  0.661538                1                   1        0.087552
# 14350       0  0.692308                1                   0        0.067415
# 85284       1  0.030769                1                   1        0.053345
# 62748       0  0.000000                1                   1        0.080806
# ...       ...       ...              ...                 ...             ...
# 60832       1  0.538462                1                   0        0.071361
# 2371        1  0.123077                1                   1        0.000000
# 26899       0  0.492308                1                   0        0.066016
# 39814       0  0.092308                1                   0        0.055758
# 20211       0  0.076923                1                   0        0.075701
#
#         Vintage  Response  Region_Code_1  Region_Code_10  Region_Code_11  ...  \
# 82374  0.588235         0              0               0               0  ...
# 81394  0.941176         0              0               0               0  ...
# 14350  0.899654         0              0               0               0  ...
# 85284  0.795848         0              0               0               0  ...
# 62748  0.332180         0              0               0               0  ...
# ...         ...       ...            ...             ...             ...  ...
# 60832  0.252595         0              0               0               0  ...
# 2371   0.235294         0              0               0               0  ...
# 26899  0.608997         1              0               0               0  ...
# 39814  0.771626         0              0               0               0  ...
# 20211  0.941176         0              0               0               0  ...
#
#        Policy_Sales_Channel_90  Policy_Sales_Channel_91  \
# 82374                        0                        0
# 81394                        0                        0
# 14350                        0                        0
# 85284                        0                        0
# 62748                        0                        0
# ...                        ...                      ...
# 60832                        0                        0
# 2371                         0                        0
# 26899                        0                        0
# 39814                        0                        0
# 20211                        0                        0
#
#        Policy_Sales_Channel_92  Policy_Sales_Channel_93  \
# 82374                        0                        0
# 81394                        0                        0
# 14350                        0                        0
# 85284                        0                        0
# 62748                        0                        0
# ...                        ...                      ...
# 60832                        0                        0
# 2371                         0                        0
# 26899                        0                        0
# 39814                        0                        0
# 20211                        0                        0
#
#        Policy_Sales_Channel_94  Policy_Sales_Channel_95  \
# 82374                        0                        0
# 81394                        0                        0
# 14350                        0                        0
# 85284                        0                        0
# 62748                        0                        0
# ...                        ...                      ...
# 60832                        0                        0
# 2371                         0                        0
# 26899                        0                        0
# 39814                        0                        0
# 20211                        0                        0
#
#        Policy_Sales_Channel_96  Policy_Sales_Channel_97  \
# 82374                        0                        0
# 81394                        0                        0
# 14350                        0                        0
# 85284                        0                        0
# 62748                        0                        0
# ...                        ...                      ...
# 60832                        0                        0
# 2371                         0                        0
# 26899                        0                        0
# 39814                        0                        0
# 20211                        0                        0
#
#        Policy_Sales_Channel_98  Policy_Sales_Channel_99
# 82374                        0                        0
# 81394                        0                        0
# 14350                        0                        0
# 85284                        0                        0
# 62748                        0                        0
# ...                        ...                      ...
# 60832                        0                        0
# 2371                         0                        0
# 26899                        0                        0
# 39814                        0                        0
# 20211                        0                        0
#
# [91466 rows x 208 columns]

# %%
import os
# if exist delete the file
if os.path.exists('data/processed/train.csv'):
    os.remove('data/processed/train.csv')
if os.path.exists('data/processed/test.csv'):
    os.remove('data/processed/test.csv')

train_df.to_csv('data/processed/train.csv', index=False)
test_df.to_csv('data/processed/test.csv', index=False)

# %%
predict = utils.check_outlier(train_df, ['Age', 'Vintage', 'Annual_Premium'])

# %%
pd.DataFrame(predict).value_counts()
# Out:
#  1    90551
# -1      915
# dtype: int64

# %%
viz_df = train_df[['Age', 'Vintage', 'Annual_Premium']].copy()
viz_df['outlier'] = predict

small_df = viz_df.sample(frac=0.01, replace=False, random_state=42).reset_index(drop=True)

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

for i in range(len(small_df)):
    if small_df.iloc[i]['outlier'] == 1:
        ax.scatter(small_df.iloc[i]['Age'], small_df.iloc[i]['Vintage'], small_df.iloc[i]['Annual_Premium'], marker='o', c = 'b')
    else:
        ax.scatter(small_df.iloc[i]['Age'], small_df.iloc[i]['Vintage'], small_df.iloc[i]['Annual_Premium'], marker='^', c = 'r')
# ax.scatter(small_df[['Age']], small_df[['Vintage']], small_df[['Annual_Premium']], marker = 'o')

ax.set_xlabel('Age')
ax.set_ylabel('Vintage')
ax.set_zlabel('Annual_Premium')
# Out:
# Text(0.5, 0, 'Annual_Premium')
