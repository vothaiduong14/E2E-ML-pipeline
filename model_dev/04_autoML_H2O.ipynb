# %%
import h2o
import mlflow
from mlflow.tracking import MlflowClient
from mlflow.entities import ViewType

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.15" 2022-04-19; OpenJDK Runtime Environment (build 11.0.15+10-Ubuntu-0ubuntu0.20.04.1); OpenJDK 64-Bit Server VM (build 11.0.15+10-Ubuntu-0ubuntu0.20.04.1, mixed mode, sharing)
#   Starting server from /home/duong/.cache/pypoetry/virtualenvs/cross-sell-TlDnGNar-py3.8/lib/python3.8/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpg19eao7k
#   JVM stdout: /tmp/tmpg19eao7k/h2o_duong_started_from_python.out
#   JVM stderr: /tmp/tmpg19eao7k/h2o_duong_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         01 secs
# H2O_cluster_timezone:       Asia/Ho_Chi_Minh
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.1.2
# H2O_cluster_version_age:    20 days
# H2O_cluster_name:           H2O_from_python_duong_3x79en
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    7.816 Gb
# H2O_cluster_total_cores:    24
# H2O_cluster_allowed_cores:  24
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.8.10 final
# --------------------------  -----------------------------

# %%
client = MlflowClient()
experiment_name = 'h2o-automl'


try: 
    experiment = client.get_experiment_by_name(experiment_name)
except:
    experiment_id = mlflow.create_experiment(experiment_name)
    experiment = client.get_experiment_by_name(experiment_name)

mlflow.set_experiment(experiment_name)
# Out:
# <Experiment: artifact_location='file:///home/duong/Desktop/GitFolder/E2E-ML-pipeline-with-data/model_dev/mlruns/2', experiment_id='2', lifecycle_stage='active', name='h2o-automl', tags={}>

# %%
train_df = h2o.import_file('data/processed/train.csv')
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
train_df['Response'] = train_df['Response'].asfactor()
y_col = 'Response'
x_col = [i for i in train_df.columns if i != y_col]

# %%
train_df
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  Gender</th><th style="text-align: right;">      Age</th><th style="text-align: right;">  Driving_License</th><th style="text-align: right;">  Previously_Insured</th><th style="text-align: right;">  Annual_Premium</th><th style="text-align: right;">  Vintage</th><th style="text-align: right;">  Response</th><th style="text-align: right;">  Region_Code_1</th><th style="text-align: right;">  Region_Code_10</th><th style="text-align: right;">  Region_Code_11</th><th style="text-align: right;">  Region_Code_12</th><th style="text-align: right;">  Region_Code_13</th><th style="text-align: right;">  Region_Code_14</th><th style="text-align: right;">  Region_Code_15</th><th style="text-align: right;">  Region_Code_16</th><th style="text-align: right;">  Region_Code_17</th><th style="text-align: right;">  Region_Code_18</th><th style="text-align: right;">  Region_Code_19</th><th style="text-align: right;">  Region_Code_2</th><th style="text-align: right;">  Region_Code_20</th><th style="text-align: right;">  Region_Code_21</th><th style="text-align: right;">  Region_Code_22</th><th style="text-align: right;">  Region_Code_23</th><th style="text-align: right;">  Region_Code_24</th><th style="text-align: right;">  Region_Code_25</th><th style="text-align: right;">  Region_Code_26</th><th style="text-align: right;">  Region_Code_27</th><th style="text-align: right;">  Region_Code_28</th><th style="text-align: right;">  Region_Code_29</th><th style="text-align: right;">  Region_Code_3</th><th style="text-align: right;">  Region_Code_30</th><th style="text-align: right;">  Region_Code_31</th><th style="text-align: right;">  Region_Code_32</th><th style="text-align: right;">  Region_Code_33</th><th style="text-align: right;">  Region_Code_34</th><th style="text-align: right;">  Region_Code_35</th><th style="text-align: right;">  Region_Code_36</th><th style="text-align: right;">  Region_Code_37</th><th style="text-align: right;">  Region_Code_38</th><th style="text-align: right;">  Region_Code_39</th><th style="text-align: right;">  Region_Code_4</th><th style="text-align: right;">  Region_Code_40</th><th style="text-align: right;">  Region_Code_41</th><th style="text-align: right;">  Region_Code_42</th><th style="text-align: right;">  Region_Code_43</th><th style="text-align: right;">  Region_Code_44</th><th style="text-align: right;">  Region_Code_45</th><th style="text-align: right;">  Region_Code_46</th><th style="text-align: right;">  Region_Code_47</th><th style="text-align: right;">  Region_Code_48</th><th style="text-align: right;">  Region_Code_49</th><th style="text-align: right;">  Region_Code_5</th><th style="text-align: right;">  Region_Code_50</th><th style="text-align: right;">  Region_Code_51</th><th style="text-align: right;">  Region_Code_52</th><th style="text-align: right;">  Region_Code_6</th><th style="text-align: right;">  Region_Code_7</th><th style="text-align: right;">  Region_Code_8</th><th style="text-align: right;">  Region_Code_9</th><th style="text-align: right;">  Vehicle_Age_lt_1_Year</th><th style="text-align: right;">  Vehicle_Age_gt_2_Years</th><th style="text-align: right;">  Vehicle_Damage_Yes</th><th style="text-align: right;">  Policy_Sales_Channel_10</th><th style="text-align: right;">  Policy_Sales_Channel_100</th><th style="text-align: right;">  Policy_Sales_Channel_101</th><th style="text-align: right;">  Policy_Sales_Channel_102</th><th style="text-align: right;">  Policy_Sales_Channel_103</th><th style="text-align: right;">  Policy_Sales_Channel_104</th><th style="text-align: right;">  Policy_Sales_Channel_105</th><th style="text-align: right;">  Policy_Sales_Channel_106</th><th style="text-align: right;">  Policy_Sales_Channel_107</th><th style="text-align: right;">  Policy_Sales_Channel_108</th><th style="text-align: right;">  Policy_Sales_Channel_109</th><th style="text-align: right;">  Policy_Sales_Channel_11</th><th style="text-align: right;">  Policy_Sal ...

# %%
from h2o.automl import H2OAutoML, get_leaderboard
with mlflow.start_run():
    clf = H2OAutoML(
                max_runtime_secs=3600,
                max_models=13,
                seed=42,
                balance_classes=True,
                sort_metric='logloss',
                verbosity='info',
                exclude_algos=['GLM', 'DRF']
        )
clf.train(x=x_col, y=y_col, training_frame=train_df)

# log metrics
mlflow.log_metric('log_loss', clf.leader.logloss())
mlflow.log_metric('auc', clf.leader.auc())
# mlflow.log_metric('f1', clf.leader.F1())

# log best model
mlflow.h2o.log_model(clf.leader, 
                        artifact_path="model"
                )

model_uri = mlflow.get_artifact_uri("model")
print(model_uri)
# Out:
# AutoML progress: |
# 12:55:46.299: Project: AutoML_1_20220616_125546
# 12:55:46.300: 5-fold cross-validation will be used.
# 12:55:46.300: Setting stopping tolerance adaptively based on the training frame: 0.0033065124063248246
# 12:55:46.300: Build control seed: 42
# 12:55:46.301: training frame: Frame key: AutoML_1_20220616_125546_training_py_1_sid_aa08    cols: 208    rows: 91466  chunks: 96    size: 3607370  checksum: -258540051354553648
# 12:55:46.301: validation frame: NULL
# 12:55:46.301: leaderboard frame: NULL
# 12:55:46.301: blending frame: NULL
# 12:55:46.301: response column: Response
# 12:55:46.301: fold column: null
# 12:55:46.301: weights column: null
# 12:55:46.310: Loading execution steps: [{XGBoost : [def_2 (1g, 10w), def_1 (2g, 10w), def_3 (3g, 10w), grid_1 (4g, 90w), lr_search (7g, 30w)]}, {GLM : [def_1 (1g, 10w)]}, {DRF : [def_1 (2g, 10w), XRT (3g, 10w)]}, {GBM : [def_5 (1g, 10w), def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w), def_1 (3g, 10w), grid_1 (4g, 60w), lr_annealing (7g, 10w)]}, {DeepLearning : [def_1 (3g, 10w), grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {completion : [resume_best_grids (6g, 60w)]}, {StackedEnsemble : [monotonic (9g, 10w), best_of_family_xglm (10g, 10w), all_xglm (10g, 10w)]}]
# 12:55:46.323: Disabling Algo: DRF as requested by the user.
# 12:55:46.323: Disabling Algo: GLM as requested by the user.
# 12:55:46.323: AutoML job created: 2022.06.16 12:55:46.284
# 12:55:46.324: AutoML build started: 2022.06.16 12:55:46.324
# 12:55:46.361: AutoML: starting XGBoost_1_AutoML_1_20220616_125546 model training
# 12:55:46.384: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_115, Policy_Sales_Channel_80, Policy_Sales_Channel_28]
#
# ███
# 12:56:20.582: New leader: XGBoost_1_AutoML_1_20220616_125546, logloss: 0.4173892035629997
# 12:56:20.588: AutoML: starting GBM_1_AutoML_1_20220616_125546 model training
# 12:56:20.602: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_115, Policy_Sales_Channel_80, Policy_Sales_Channel_28]
#
# ██
# 12:57:04.604: New leader: GBM_1_AutoML_1_20220616_125546, logloss: 0.26896492867637006
# 12:57:04.606: AutoML: starting XGBoost_2_AutoML_1_20220616_125546 model training
# 12:57:04.607: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_115, Policy_Sales_Channel_80, Policy_Sales_Channel_28]
#
# █
# 12:57:37.434: AutoML: starting GBM_2_AutoML_1_20220616_125546 model training
# 12:57:37.435: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_115, Policy_Sales_Channel_80, Policy_Sales_Channel_28]
#
# ██
# 12:57:55.350: New leader: GBM_2_AutoML_1_20220616_125546, logloss: 0.26713228959336055
# 12:57:55.351: AutoML: starting GBM_3_AutoML_1_20220616_125546 model training
# 12:57:55.352: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_115, Policy_Sales_Channel_80, Policy_Sales_Channel_28]
#
# █
# 12:58:13.636: AutoML: starting GBM_4_AutoML_1_20220616_125546 model training
# 12:58:13.637: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_115, Policy_Sales_Channel_80, Policy_Sales_Channel_28]
#
# █
# 12:58:35.411: AutoML: starting XGBoost_3_AutoML_1_20220616_125546 model training
# 12:58:35.411: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_115, Policy_Sales_Channel_80, Policy_Sales_Channel_28]
#
# █
# 12:58:46.643: AutoML: starting GBM_5_AutoML_1_20220616_125546 model training
# 12:58:46.644: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_115, Policy_Sales_Channel_80, Policy_Sales_Channel_28]
#
# ██
# 12:59:02.254: AutoML: starting DeepLearning_1_AutoML_1_20220616_125546 model training
# 12:59:02.255: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_115, Policy_Sales_Channel_80, Policy_Sales_Channel_28]
#
# ███
# 12:59:22.63: AutoML: starting XGBoost_grid_1_AutoML_1_20220616_125546 hyperparameter search
# 12:59:30.75: New leader: XGBoost_grid_1_AutoML_1_20220616_125546_model_1, logloss: 0.26680946781372517
# 12:59:38.315: AutoML: starting GBM_grid_1_AutoML_1_20220616_125546 hyperparameter search
#
# ████████████████
# 12:59:53.17: AutoML: starting DeepLearning_grid_1_AutoML_1_20220616_125546 hyperparameter search
#
# █████████████████████████
# 13:06:39.999: No base models, due to timeouts or the exclude_algos option. Skipping StackedEnsemble 'monotonic'.
# 13:06:40.5: AutoML: starting StackedEnsemble_BestOfFamily_1_AutoML_1_20220616_125546 model training
# 13:06:40.6: _train param, Dropping unused columns: [Policy_Sales_Channel_115, Policy_Sales_Channel_80, Policy_Sales_Channel_28]
#
# █
# 13:06:48.875: New leader: StackedEnsemble_BestOfFamily_1_AutoML_1_20220616_125546, logloss: 0.2661876534471731
# 13:06:48.876: AutoML: starting StackedEnsemble_AllModels_1_AutoML_1_20220616_125546 model training
# 13:06:48.877: _train param, Dropping unused columns: [Policy_Sales_Channel_115, Policy_Sales_Channel_80, Policy_Sales_Channel_28]
#
# █████| (done) 100%
#
# 13:06:58.171: New leader: StackedEnsemble_AllModels_1_AutoML_1_20220616_125546, logloss: 0.26610426647822405
# 13:06:58.171: Actual modeling steps: [{XGBoost : [def_2 (1g, 10w)]}, {GBM : [def_5 (1g, 10w)]}, {XGBoost : [def_1 (2g, 10w)]}, {GBM : [def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w)]}, {XGBoost : [def_3 (3g, 10w)]}, {GBM : [def_1 (3g, 10w)]}, {DeepLearning : [def_1 (3g, 10w)]}, {XGBoost : [grid_1 (4g, 90w)]}, {GBM : [grid_1 (4g, 60w)]}, {DeepLearning : [grid_1 (4g, 30w)]}, {StackedEnsemble : [best_of_family_xglm (10g, 10w), all_xglm (10g, 10w)]}]
# 13:06:58.171: AutoML build stopped: 2022.06.16 13:06:58.171
# 13:06:58.171: AutoML build done: built 13 models
# 13:06:58.171: AutoML duration: 11 min 11.847 sec
#
# file:///home/duong/Desktop/GitFolder/E2E-ML-pipeline-with-data/model_dev/mlruns/2/012f282032aa451a9eb7d69e89c86530/artifacts/model
# /home/duong/.cache/pypoetry/virtualenvs/cross-sell-TlDnGNar-py3.8/lib/python3.8/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %%
lb = get_leaderboard(clf, extra_columns='all')
lb.head()
# Out:
# <table>
# <thead>
# <tr><th>model_id                                               </th><th style="text-align: right;">  logloss</th><th style="text-align: right;">     auc</th><th style="text-align: right;">   aucpr</th><th style="text-align: right;">  mean_per_class_error</th><th style="text-align: right;">    rmse</th><th style="text-align: right;">      mse</th><th style="text-align: right;">  training_time_ms</th><th style="text-align: right;">  predict_time_per_row_ms</th><th>algo           </th></tr>
# </thead>
# <tbody>
# <tr><td>StackedEnsemble_AllModels_1_AutoML_1_20220616_125546   </td><td style="text-align: right;"> 0.266104</td><td style="text-align: right;">0.857219</td><td style="text-align: right;">0.368396</td><td style="text-align: right;">              0.223137</td><td style="text-align: right;">0.295198</td><td style="text-align: right;">0.0871417</td><td style="text-align: right;">              9282</td><td style="text-align: right;">                 0.009304</td><td>StackedEnsemble</td></tr>
# <tr><td>StackedEnsemble_BestOfFamily_1_AutoML_1_20220616_125546</td><td style="text-align: right;"> 0.266188</td><td style="text-align: right;">0.857016</td><td style="text-align: right;">0.36848 </td><td style="text-align: right;">              0.22976 </td><td style="text-align: right;">0.295241</td><td style="text-align: right;">0.087167 </td><td style="text-align: right;">              8849</td><td style="text-align: right;">                 0.002185</td><td>StackedEnsemble</td></tr>
# <tr><td>XGBoost_grid_1_AutoML_1_20220616_125546_model_1        </td><td style="text-align: right;"> 0.266809</td><td style="text-align: right;">0.856194</td><td style="text-align: right;">0.365215</td><td style="text-align: right;">              0.229777</td><td style="text-align: right;">0.295496</td><td style="text-align: right;">0.0873176</td><td style="text-align: right;">               855</td><td style="text-align: right;">                 0.000604</td><td>XGBoost        </td></tr>
# <tr><td>GBM_2_AutoML_1_20220616_125546                         </td><td style="text-align: right;"> 0.267132</td><td style="text-align: right;">0.856204</td><td style="text-align: right;">0.367831</td><td style="text-align: right;">              0.234975</td><td style="text-align: right;">0.295575</td><td style="text-align: right;">0.0873645</td><td style="text-align: right;">              2894</td><td style="text-align: right;">                 0.001244</td><td>GBM            </td></tr>
# <tr><td>XGBoost_grid_1_AutoML_1_20220616_125546_model_2        </td><td style="text-align: right;"> 0.267266</td><td style="text-align: right;">0.855338</td><td style="text-align: right;">0.36108 </td><td style="text-align: right;">              0.229424</td><td style="text-align: right;">0.295903</td><td style="text-align: right;">0.0875585</td><td style="text-align: right;">               897</td><td style="text-align: right;">                 0.000634</td><td>XGBoost        </td></tr>
# <tr><td>GBM_grid_1_AutoML_1_20
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.08714172606022363
# RMSE: 0.2951977744838596
# LogLoss: 0.26610426647822405
# Null degrees of freedom: 91465
# Residual degrees of freedom: 91452
# Null deviance: 68369.8558411503
# Residual deviance: 48678.98567539448
# AIC: 48706.98567539448
# AUC: 0.8572194128417331
# AUCPR: 0.36839648043318485
# Gini: 0.7144388256834662
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.22549844386231496:
#                 0        1   Error                Rate
# 0      0  62005.0  18170.0  0.2266   (18170.0/80175.0)
# 1      1   2480.0   8811.0  0.2196    (2480.0/11291.0)
# 2  Total  64485.0  26981.0  0.2258   (20650.0/91466.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.225498      0.460441  207.0
# 1                        max f2   0.134324      0.639933  276.0
# 2                  max f0point5   0.319044      0.389886  124.0
# 3                  max accuracy   0.617475      0.876566    0.0
# 4                 max precision   0.617475      1.000000    0.0
# 5                    max recall   0.000442      1.000000  398.0
# 6               max specificity   0.617475      1.000000    0.0
# 7              max absolute_mcc   0.145166      0.405790  268.0
# 8    max min_per_class_accuracy   0.227020      0.774531  206.0
# 9   max mean_per_class_accuracy   0.134324      0.800270  276.0
# 10                      max tns   0.617475  80175.000000    0.0
# 11                      max fns   0.617475  11290.000000    0.0
# 12                      max fps   0.000281  80175.000000  399.0
# 13                      max tps   0.000442  11291.000000  398.0
# 14                      max tnr   0.617475      1.000000    0.0
# 15                      max fnr   0.617475      0.999911    0.0
# 16                      max fpr   0.000281      1.000000  399.0
# 17                      max tpr   0.000442      1.000000  398.0
# Gains/Lift Table: Avg response rate: 12.34 %, avg score: 12.35 %
#     group  cumulative_data_fraction  lower_threshold      lift  \
# 0       1                  0.010004         0.424359  3.762661
# 1       2                  0.020007         0.404439  3.700688
# 2       3                  0.030000         0.392044  3.359080
# 3       4                  0.040004         0.382934  3.054396
# 4       5                  0.050008         0.375961  3.258022
# 5       6                  0.100004         0.346910  3.000817
# 6       7                  0.150001         0.320081  2.696129
# 7       8                  0.200009         0.295077  2.502495
# 8       9                  0.300002         0.220530  2.065497
# 9      10                  0.400007         0.127907  1.374486
# 10     11                  0.500000         0.034415  0.638604
# 11     12                  0.600004         0.001339  0.096533
# 12     13                  0.699998         0.000845  0.005314
# 13     14                  0.800002         0.000644  0.002657
# 14     15                  0.900017         0.000477  0.001771
# 15     16                  1.000000         0.000070  0.001772
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0          3.762661       0.464481  0.449677                  0.464481
# 1          3.731675       0.456831  0.413351                  0.460656
# 2          3.607567       0.414661  0.398113                  0.445335
# 3          3.469236       0.377049  0.387360                  0.428259
# 4          3.426984       0.402186  0.379313                  0.423043
# 5          3.213924       0.370435  0.361399                  0.396742
# 6          3.041338       0.332823  0.333351                  0.375437
# 7          2.906613       0.308920  0.307922                  0.358806
# 8          2.626261       0.254975  0.261005                  0.324198
# 9          2.313309       0.169673  0.174085                  0.285566
# 10         1.978390       0.078832  0.080198                  0.244222
# 11         1.664736       0.011916  0.012401                  0.205503
# 12         1.427690       0.000656  0.001031                  0.176241
# 13         1.249554       0.000328  0.000738                  0.154251
# 14         1.110893       0.000219  0.000562                  0.137134
# 15         1.000000       0.000219  0.000354                  0.123445
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain  \
# 0           0
# 14  13531.112000  13676.484000  13674.973000  13904.471000
# 15      0.363080      0.363194      0.362595      0.401711
# 16      0.321140      0.323720      0.324871      0.354688
# 17      0.193240      0.192746      0.192395      0.210879
# 18      0.807848      0.777876      0.778316      0.752697
# 19   9614.357000   9737.912000   9763.038000   9724.644000
# See the whole table with table.as_data_frame()

# %%
# predict
test_df = h2o.import_file('data/processed/test.csv')
X_test = test_df.drop('Response')
y_test = test_df['Response']

# %%
# Get dataframe of all runs
all_experiments = [exp.experiment_id for exp in client.list_experiments()]
runs = mlflow.search_runs(experiment_ids=all_experiments, run_view_type=ViewType.ALL)

# Identify best model (experiment id and run id) amongst all runs in the experiment
run_id, exp_id = runs.loc[runs['metrics.log_loss'].idxmin()]['run_id'], runs.loc[runs['metrics.log_loss'].idxmin()]['experiment_id']
run_id, exp_id
# Out:
# ('012f282032aa451a9eb7d69e89c86530', '2')

# %%
best_model = mlflow.h2o.load_model(f"mlruns/{exp_id}/{run_id}/artifacts/model/")

# %%
preds = best_model.predict(X_test)
# Out:
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%

# %%
y_pred = preds.as_data_frame()['predict']
y_true = y_test.as_data_frame()['Response']

# %%
from sklearn.metrics import confusion_matrix as cm
cm = cm(y_true, y_pred)
print(cm)
# Out:
# [[15605  4415]
#  [  646  2201]]

# %%
cm.ravel()
# Out:
# array([15605,  4415,   646,  2201])

# %%
mlflow.end_run()

# %%
mlflow.h2o.save_model(best_model, "models")
# Out:
# /home/duong/.cache/pypoetry/virtualenvs/cross-sell-TlDnGNar-py3.8/lib/python3.8/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %%
from mlflow import h2o
loaded_model = h2o.load_model(f'mlruns/{exp_id}/{run_id}/artifacts/model')

# %%
y_predict = loaded_model.predict(X_test)

# %%
y_predict
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th><th style="text-align: right;">      p0</th><th style="text-align: right;">         p1</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.643388</td><td style="text-align: right;">0.356612   </td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.999628</td><td style="text-align: right;">0.000371702</td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.999438</td><td style="text-align: right;">0.000562257</td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.754659</td><td style="text-align: right;">0.245341   </td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.862737</td><td style="text-align: right;">0.137263   </td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.999217</td><td style="text-align: right;">0.000782751</td></tr>
# <tr><td style="text-align: right;">        0</td><td style="text-align: right;">0.999696</td><td style="text-align: right;">0.000304332</td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.757598</td><td style="text-align: right;">0.242402   </td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.612998</td><td style="text-align: right;">0.387002   </td></tr>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">0.668583</td><td style="text-align: right;">0.331417   </td></tr>
# </tbody>
# </table>

# %%
import pandas as pd
test_df = pd.read_csv('data/processed/test.csv')
X_test = test_df.drop(['Response'], axis=1)
y_test = test_df['Response']

# %%
from mlflow import pyfunc
loaded_model = pyfunc.load_model(f'mlruns/{exp_id}/{run_id}/artifacts/model')
y_predict = loaded_model.predict(X_test)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         2 hours 18 mins
# H2O_cluster_timezone:       Asia/Ho_Chi_Minh
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.1.2
# H2O_cluster_version_age:    21 days and 23 minutes
# H2O_cluster_name:           H2O_from_python_duong_3x79en
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    7.384 Gb
# H2O_cluster_total_cores:    24
# H2O_cluster_allowed_cores:  24
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.8.10 final
# --------------------------  -----------------------------

# %%
y_predict['predict']
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 22862    1
# 22863    1
# 22864    1
# 22865    1
# 22866    0
# Name: predict, Length: 22867, dtype: int64
