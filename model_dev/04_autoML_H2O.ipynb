# %%
import h2o
import mlflow
from mlflow.tracking import MlflowClient
from mlflow.entities import ViewType

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.15" 2022-04-19; OpenJDK Runtime Environment (build 11.0.15+10-Ubuntu-0ubuntu0.20.04.1); OpenJDK 64-Bit Server VM (build 11.0.15+10-Ubuntu-0ubuntu0.20.04.1, mixed mode, sharing)
#   Starting server from /home/duong/.cache/pypoetry/virtualenvs/cross-sell-TlDnGNar-py3.8/lib/python3.8/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmp4kmwyhht
#   JVM stdout: /tmp/tmp4kmwyhht/h2o_duong_started_from_python.out
#   JVM stderr: /tmp/tmp4kmwyhht/h2o_duong_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------
# H2O_cluster_uptime:         01 secs
# H2O_cluster_timezone:       Asia/Ho_Chi_Minh
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.1.2
# H2O_cluster_version_age:    19 days
# H2O_cluster_name:           H2O_from_python_duong_kn1x1c
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    7.816 Gb
# H2O_cluster_total_cores:    24
# H2O_cluster_allowed_cores:  24
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.8.10 final
# --------------------------  -----------------------------

# %%
client = MlflowClient()
experiment_name = 'h2o-automl'


try: 
    experiment = client.get_experiment_by_name(experiment_name)
except:
    experiment_id = mlflow.create_experiment(experiment_name)
    experiment = client.get_experiment_by_name(experiment_name)

mlflow.set_experiment(experiment_name)
# Out:
# <Experiment: artifact_location='file:///home/duong/Desktop/GitFolder/E2E-ML-pipeline-with-data/model_dev/mlruns/2', experiment_id='2', lifecycle_stage='active', name='h2o-automl', tags={}>

# %%
train_df = h2o.import_file('data/processed/train.csv')
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
train_df['Response'] = train_df['Response'].asfactor()
y_col = 'Response'
x_col = [i for i in train_df.columns if i != y_col]

# %%
from h2o.automl import H2OAutoML, get_leaderboard
with mlflow.start_run():
    clf = H2OAutoML(
                max_runtime_secs=3600,
                max_models=13,
                seed=42,
                balance_classes=True,
                sort_metric='logloss',
                verbosity='info',
                exclude_algos=['GLM', 'DRF']
        )
clf.train(x=x_col, y=y_col, training_frame=train_df)

# log metrics
mlflow.log_metric('log_loss', clf.leader.logloss())
mlflow.log_metric('auc', clf.leader.auc())
# mlflow.log_metric('f1', clf.leader.F1())

# log best model
mlflow.h2o.log_model(clf.leader, 
                        artifact_path="model"
                )

model_uri = mlflow.get_artifact_uri("model")
print(model_uri)
# Out:
# AutoML progress: |
# 01:39:32.732: Project: AutoML_5_20220615_13932
# 01:39:32.732: 5-fold cross-validation will be used.
# 01:39:32.733: Setting stopping tolerance adaptively based on the training frame: 0.0033065124063248246
# 01:39:32.733: Build control seed: 42
# 01:39:32.733: training frame: Frame key: AutoML_5_20220615_13932_training_py_9_sid_8647    cols: 208    rows: 91466  chunks: 96    size: 3596833  checksum: -1078902510547953999
# 01:39:32.733: validation frame: NULL
# 01:39:32.733: leaderboard frame: NULL
# 01:39:32.733: blending frame: NULL
# 01:39:32.733: response column: Response
# 01:39:32.733: fold column: null
# 01:39:32.733: weights column: null
# 01:39:32.734: Loading execution steps: [{XGBoost : [def_2 (1g, 10w), def_1 (2g, 10w), def_3 (3g, 10w), grid_1 (4g, 90w), lr_search (7g, 30w)]}, {GLM : [def_1 (1g, 10w)]}, {DRF : [def_1 (2g, 10w), XRT (3g, 10w)]}, {GBM : [def_5 (1g, 10w), def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w), def_1 (3g, 10w), grid_1 (4g, 60w), lr_annealing (7g, 10w)]}, {DeepLearning : [def_1 (3g, 10w), grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {completion : [resume_best_grids (6g, 60w)]}, {StackedEnsemble : [monotonic (9g, 10w), best_of_family_xglm (10g, 10w), all_xglm (10g, 10w)]}]
# 01:39:32.734: Disabling Algo: GLM as requested by the user.
# 01:39:32.734: Disabling Algo: DRF as requested by the user.
# 01:39:32.734: AutoML job created: 2022.06.15 01:39:32.732
# 01:39:32.736: AutoML build started: 2022.06.15 01:39:32.736
# 01:39:32.738: AutoML: starting XGBoost_1_AutoML_5_20220615_13932 model training
# 01:39:32.738: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_80, Gender, Policy_Sales_Channel_115, Policy_Sales_Channel_28]
#
# ███
# 01:40:14.702: New leader: XGBoost_1_AutoML_5_20220615_13932, logloss: 0.4167298102586204
# 01:40:14.704: AutoML: starting GBM_1_AutoML_5_20220615_13932 model training
# 01:40:14.704: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_80, Gender, Policy_Sales_Channel_115, Policy_Sales_Channel_28]
#
# █
# 01:40:45.323: New leader: GBM_1_AutoML_5_20220615_13932, logloss: 0.26898050991231354
# 01:40:45.324: AutoML: starting XGBoost_2_AutoML_5_20220615_13932 model training
# 01:40:45.325: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_80, Gender, Policy_Sales_Channel_115, Policy_Sales_Channel_28]
#
# █
# 01:41:18.288: AutoML: starting GBM_2_AutoML_5_20220615_13932 model training
# 01:41:18.289: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_80, Gender, Policy_Sales_Channel_115, Policy_Sales_Channel_28]
#
# █
# 01:41:35.368: New leader: GBM_2_AutoML_5_20220615_13932, logloss: 0.26747267508008066
# 01:41:35.370: AutoML: starting GBM_3_AutoML_5_20220615_13932 model training
# 01:41:35.370: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_80, Gender, Policy_Sales_Channel_115, Policy_Sales_Channel_28]
#
# ██
# 01:41:54.143: AutoML: starting GBM_4_AutoML_5_20220615_13932 model training
# 01:41:54.144: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_80, Gender, Policy_Sales_Channel_115, Policy_Sales_Channel_28]
#
# █
# 01:42:15.677: AutoML: starting XGBoost_3_AutoML_5_20220615_13932 model training
# 01:42:15.677: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_80, Gender, Policy_Sales_Channel_115, Policy_Sales_Channel_28]
#
# █
# 01:42:28.252: AutoML: starting GBM_5_AutoML_5_20220615_13932 model training
# 01:42:28.252: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_80, Gender, Policy_Sales_Channel_115, Policy_Sales_Channel_28]
#
# ██
# 01:42:43.878: New leader: GBM_5_AutoML_5_20220615_13932, logloss: 0.26743511255328895
# 01:42:43.890: AutoML: starting DeepLearning_1_AutoML_5_20220615_13932 model training
# 01:42:43.890: _train param, Dropping bad and constant columns: [Policy_Sales_Channel_80, Gender, Policy_Sales_Channel_115, Policy_Sales_Channel_28]
#
# ███
# 01:43:04.385: AutoML: starting XGBoost_grid_1_AutoML_5_20220615_13932 hyperparameter search
# 01:43:12.402: New leader: XGBoost_grid_1_AutoML_5_20220615_13932_model_1, logloss: 0.26694057820312256
# 01:43:18.344: AutoML: starting GBM_grid_1_AutoML_5_20220615_13932 hyperparameter search
#
# ████████████████
# 01:43:33.173: AutoML: starting DeepLearning_grid_1_AutoML_5_20220615_13932 hyperparameter search
#
# █████████████████████████
# 01:49:39.436: No base models, due to timeouts or the exclude_algos option. Skipping StackedEnsemble 'monotonic'.
# 01:49:39.438: AutoML: starting StackedEnsemble_BestOfFamily_1_AutoML_5_20220615_13932 model training
# 01:49:39.438: _train param, Dropping unused columns: [Policy_Sales_Channel_80, Gender, Policy_Sales_Channel_115, Policy_Sales_Channel_28]
#
# ██
# 01:49:47.525: New leader: StackedEnsemble_BestOfFamily_1_AutoML_5_20220615_13932, logloss: 0.26649197118057805
# 01:49:47.526: AutoML: starting StackedEnsemble_AllModels_1_AutoML_5_20220615_13932 model training
# 01:49:47.527: _train param, Dropping unused columns: [Policy_Sales_Channel_80, Gender, Policy_Sales_Channel_115, Policy_Sales_Channel_28]
#
# █████| (done) 100%
#
# 01:49:57.19: New leader: StackedEnsemble_AllModels_1_AutoML_5_20220615_13932, logloss: 0.2663165059098335
# 01:49:57.19: Actual modeling steps: [{XGBoost : [def_2 (1g, 10w)]}, {GBM : [def_5 (1g, 10w)]}, {XGBoost : [def_1 (2g, 10w)]}, {GBM : [def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w)]}, {XGBoost : [def_3 (3g, 10w)]}, {GBM : [def_1 (3g, 10w)]}, {DeepLearning : [def_1 (3g, 10w)]}, {XGBoost : [grid_1 (4g, 90w)]}, {GBM : [grid_1 (4g, 60w)]}, {DeepLearning : [grid_1 (4g, 30w)]}, {StackedEnsemble : [best_of_family_xglm (10g, 10w), all_xglm (10g, 10w)]}]
# 01:49:57.19: AutoML build stopped: 2022.06.15 01:49:57.19
# 01:49:57.19: AutoML build done: built 13 models
# 01:49:57.19: AutoML duration: 10 min 24.283 sec
#
# file:///home/duong/Desktop/GitFolder/E2E-ML-pipeline-with-data/model_dev/mlruns/2/79c6925b6519401db319a61d4998a7ba/artifacts/model

# %%
lb = get_leaderboard(clf, extra_columns='all')
lb.head()
# Out:
# <table>
# <thead>
# <tr><th>model_id                                              </th><th style="text-align: right;">  logloss</th><th style="text-align: right;">     auc</th><th style="text-align: right;">   aucpr</th><th style="text-align: right;">  mean_per_class_error</th><th style="text-align: right;">    rmse</th><th style="text-align: right;">      mse</th><th style="text-align: right;">  training_time_ms</th><th style="text-align: right;">  predict_time_per_row_ms</th><th>algo           </th></tr>
# </thead>
# <tbody>
# <tr><td>StackedEnsemble_AllModels_1_AutoML_5_20220615_13932   </td><td style="text-align: right;"> 0.266317</td><td style="text-align: right;">0.857021</td><td style="text-align: right;">0.367406</td><td style="text-align: right;">              0.228974</td><td style="text-align: right;">0.295279</td><td style="text-align: right;">0.0871899</td><td style="text-align: right;">              9481</td><td style="text-align: right;">                 0.006747</td><td>StackedEnsemble</td></tr>
# <tr><td>StackedEnsemble_BestOfFamily_1_AutoML_5_20220615_13932</td><td style="text-align: right;"> 0.266492</td><td style="text-align: right;">0.856847</td><td style="text-align: right;">0.367662</td><td style="text-align: right;">              0.230014</td><td style="text-align: right;">0.295329</td><td style="text-align: right;">0.0872193</td><td style="text-align: right;">              8076</td><td style="text-align: right;">                 0.001838</td><td>StackedEnsemble</td></tr>
# <tr><td>XGBoost_grid_1_AutoML_5_20220615_13932_model_1        </td><td style="text-align: right;"> 0.266941</td><td style="text-align: right;">0.855948</td><td style="text-align: right;">0.364598</td><td style="text-align: right;">              0.23198 </td><td style="text-align: right;">0.295559</td><td style="text-align: right;">0.0873553</td><td style="text-align: right;">               779</td><td style="text-align: right;">                 0.000581</td><td>XGBoost        </td></tr>
# <tr><td>XGBoost_grid_1_AutoML_5_20220615_13932_model_2        </td><td style="text-align: right;"> 0.267374</td><td style="text-align: right;">0.855214</td><td style="text-align: right;">0.359536</td><td style="text-align: right;">              0.227673</td><td style="text-align: right;">0.29601 </td><td style="text-align: right;">0.0876217</td><td style="text-align: right;">               862</td><td style="text-align: right;">                 0.000567</td><td>XGBoost        </td></tr>
# <tr><td>GBM_grid_1_AutoML_5_20220615_13932_model_1            </td><td style="text-align: right;"> 0.267426</td><td style="text-align: right;">0.855763</td><td style="text-align: right;">0.365725</td><td style="text-align: right;">              0.231263</td><td style="text-align: right;">0.295726</td><td style="text-align: right;">0.087454 </td><td style="text-align: right;">              2386</td><td style="text-align: right;">                 0.001249</td><td>GBM            </td></tr>
# <tr><td>GBM_5_AutoML_5_20220615_13932                         </td><td style="text-align: right;"> 0.267435</td><td style="text-align: right;">0.855685</td><td style="text-align: right;">0.366115</td><td style="text-align: right;">              0.231823</td><td style="text-align: right;">0.295762</td><td style="text-align: right;">0.0874752</td><td style="text-align: right;">              2771</td><td style="text-align: right;">                 0.001311</td><td>GBM            </td></tr>
# <tr><td>GBM_2_AutoML_5_20220615_13932                         </td><td style="text-align: right;"> 0.267473</td><td style="text-align: right;">0.855818</td><td style="text-align: right;">0.366347</td><td style="text-align: right;">              0.241591</td><td style="text-align: right;">0.295717</td><td style="text-align: right;">0.0874484</td><td style="text-align: right;">              3005</td><td style="text-align: right;">                 0.001204</td><td>GBM            </td></tr>
# <tr><td>GBM_3_AutoML_5_20220615_13932                         </td><td style="text-align: right;"> 0.267691</td><td style="text-align: right;">0.855805</td><td style="text-align: right;">0.367635</td><td style="text-align: right;">              0.23417 </td><td style="text-align: right;">0.295743</td><td style="text-align: right;">0.0874638</td><td style="text-align: right;">              2982</td><td style="text-align: right;">                 0.00125 </td><td>GBM            </td></tr>
# <tr><td>GBM_1_AutoML_5_20220615_13932                         </td><td style="text-align: right;"> 0.268981</td><td style="text-align: right;">0.853547</td><td style="text-align: right;">0.361923</td><td style="text-align: right;">              0.236233</td><td style="text-align: right;">0.296404</td><td style="text-align: right;">0.0878554</td><td style="text-align: right;">              5024</td><td style="text-align: right;">                 0.001671</td><td>GBM            </td></tr>
# <tr><td>GBM_4_AutoML_5_20220615_13932                         </td><td style="text-align: right;"> 0.269303</td><td style="text-align: right;">0.854347</td><td style="text-align: right;">0.362843</td><td style="text-align: right;">              0.230766</td><td style="text-align: right;">0.296299</td><td style="text-align: right;">0.0877933</td><td style="text-align: right;">              3340</td><td style="text-align: right;">                 0.00118 </td><td>GBM            </td></tr>
# </tbody>
# </table>

# %%
clf.leader
# Out:
# Model Details
# =============
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_AllModels_1_AutoML_5_20220615_13932
#
# No model summary for this model
#
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.08404998845418953
# RMSE: 0.28991376037399386
# LogLoss: 0.25697248180153504
# Null degrees of freedom: 9974
# Residual degrees of freedom: 9964
# Null deviance: 7360.460475191961
# Residual deviance: 5126.601011940624
# AIC: 5148.601011940624
# AUC: 0.8695502096952691
# AUCPR: 0.4061097648176061
# Gini: 0.7391004193905382
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.2735832950671382:
#                0       1   Error              Rate
# 0      0  7250.0  1518.0  0.1731   (1518.0/8768.0)
# 1      1   356.0   851.0  0.2949    (356.0/1207.0)
# 2  Total  7606.0  2369.0  0.1879   (1874.0/9975.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold        value    idx
# 0                        max f1   0.273583     0.475951  168.0
# 1                        max f2   0.165407     0.644397  255.0
# 2                  max f0point5   0.307282     0.412774  135.0
# 3                  max accuracy   0.410666     0.882306   40.0
# 4                 max precision   0.505883     0.750000    7.0
# 5                    max recall   0.003224     1.000000  390.0
# 6               max specificity   0.579751     0.999886    0.0
# 7              max absolute_mcc   0.211449     0.419941  221.0
# 8    max min_per_class_accuracy   0.241425     0.788663  197.0
# 9   max mean_per_class_accuracy   0.165407     0.806658  255.0
# 10                      max tns   0.579751  8767.000000    0.0
# 11                      max fns   0.579751  1207.000000    0.0
# 12                      max fps   0.000305  8768.000000  399.0
# 13                      max tps   0.003224  1207.000000  390.0
# 14                      max tnr   0.579751     0.999886    0.0
# 15                      max fnr   0.579751     1.000000    0.0
# 16                      max fpr   0.000305     1.000000  399.0
# 17                      max tpr   0.003224     1.000000  390.0
# Gains/Lift Table: Avg response rate: 12.10 %, avg score: 12.51 %
#     group  cumulative_data_fraction  lower_threshold      lift  \
# 0       1                  0.010025         0.429303  5.123861
# 1       2                  0.020050         0.408906  4.462717
# 2       3                  0.030075         0.394657  3.305717
# 3       4                  0.040000         0.385796  4.257362
# 4       5                  0.050025         0.378242  2.644573
# 5       6                  0.100050         0.347255  2.865175
# 6       7                  0.150075         0.321654  3.014231
# 7       8                  0.200000         0.297035  2.555624
# 8       9                  0.300050         0.223667  1.954281
# 9      10                  0.400000         0.130167  1.201928
# 10     11                  0.500050         0.038404  0.621064
# 11     12                  0.600000         0.001205  0.024867
# 12     13                  0.699950         0.000734  0.000000
# 13     14                  0.800000         0.000567  0.000000
# 14     15                  0.899950         0.000442  0.000000
# 15     16                  1.000000         0.000080  0.000000
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0          5.123861       0.620000  0.455447                  0.620000
# 1          4.793289       0.540000  0.417489                  0.580000
# 2          4.297432       0.400000  0.401371                  0.520000
# 3          4.287490       0.515152  0.390234                  0.518797
# 4          3.958248       0.320000  0.381750                  0.478958
# 5          3.411712       0.346693  0.362951                  0.412826
# 6          3.279218       0.364729  0.334209                  0.396794
# 7          3.098592       0.309237  0.309663                  0.374937
# 8          2.717027       0.236473  0.263174                  0.328767
# 9          2.338442       0.145436  0.176810                  0.282957
# 10         1.994829       0.075150  0.085805                  0.241379
# 11         1.666667       0.003009  0.014344                  0.201671
# 12         1.428674       0.000000  0.000880                  0.172873
# 13         1.250000       0.000000  0.000644                  0.151253
# 14         1.111173       0.000000  0.000505                  0.134455
# 15         1.000000       0.000000  0.000340                  0.121003
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain  \
# 0           0.455447      0.051367                 0.051367  412.386081
# 1           0.436468      0.044739                 0.096106  346.271748
# 2           0.424769      0.033140                 0.129246  230.571665
# 3           0.416200      0.042254                 0.171500  325.736236
# 4           0.409296      0.026512                 0.198012  164.457332
# 5           0.386124      0.143331                 0.341342  186.517526
# 6           0.368819      0.150787                 0.492129  201.423062
# 7           0.354052      0.127589                 0.619718  155.562432
# 8           0.323749      0.195526                 0.815244   95.428139
# 9           0.287033      0.120133                 0.935377   20.192807
# 10          0.246771      0.062138                 0.997514  -37.893600
# 11          0.208053      0.002486                 1.000000  -97.513252
# 12          0.178469      0.000000                 1.000000 -100.000000
# 13          0.156230      0.000000                 1.000000 -100.000000
# 14          0.138935      0.000000                 1.000000 -100.000000
# 15          0.125068      0.000000                 1.000000 -100.000000
#
#     cumulative_gain  kolmogorov_smirnov
# 0        412.386081            0.047033
# 1        379.328915            0.086526
# 2        329.743165            0.112823
# 3        328.748964            0.149602
# 4        295.824790            0.168358
# 5        241.171158            0.274508
# 6        227.921792            0.389141
# 7        209.859155            0.477497
# 8        171.702739            0.586116
# 9        133.844242            0.609077
# 10        99.482901            0.565945
# 11        66.666667            0.455064
# 12        42.867373            0.341355
# 13        25.000000            0.227532
# 14        11.117300            0.113823
# 15         0.000000            0.000000
# ModelMetricsBinomialGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 0.08718992504946824
# RMSE: 0.2952794016680951
# LogLoss: 0.2663165059098335
# Null degrees of freedom: 91465
# Residual degrees of freedom: 91453
# Null deviance: 68369.8558411503
# Residual deviance: 48717.811059097665
# AIC: 48743.811059097665
# AUC: 0.8570206668351826
# AUCPR: 0.3674058068903915
# Gini: 0.7140413336703653
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.23638010623671257:
#                 0        1   Error                Rate
# 0      0  62901.0  17274.0  0.2155   (17274.0/80175.0)
# 1      1   2738.0   8553.0  0.2425    (2738.0/11291.0)
# 2  Total  65639.0  25827.0  0.2188   (20012.0/91466.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold         value    idx
# 0                        max f1   0.236380      0.460855  198.0
# 1                        max f2   0.119188      0.638248  290.0
# 2                  max f0point5   0.305238      0.389641  136.0
# 3                  max accuracy   0.670512      0.876566    0.0
# 4                 max precision   0.670512      1.000000    0.0
# 5                    max recall   0.000670      1.000000  397.0
# 6               max specificity   0.670512      1.000000    0.0
# 7              max absolute_mcc   0.174254      0.404617  246.0
# 8    max min_per_class_accuracy   0.227315      0.774980  205.0
# 9   max mean_per_class_accuracy   0.119188      0.799267  290.0
# 10                      max tns   0.670512  80175.000000    0.0
# 11                      max fns   0.670512  11290.000000    0.0
# 12                      max fps   0.000374  80175.000000  399.0
# 13                      max tps   0.000670  11291.000000  397.0
# 14                      max tnr   0.670512      1.000000    0.0
# 15                      max fnr   0.670512      0.999911    0.0
# 16                      max fpr   0.000374      1.000000  399.0
# 17                      max tpr   0.000670      1.000000  397.0
# Gains/Lift Table: Avg response rate: 12.34 %, avg score: 12.35 %
#     group  cumulative_data_fraction  lower_threshold      lift  \
# 0       1                  0.010004         0.424392  3.612155
# 1       2                  0.020007         0.404690  3.603301
# 2       3                  0.030000         0.392369  3.545203
# 3       4                  0.040004         0.382189  3.373115
# 4       5                  0.050008         0.374311  3.328849
# 5       6                  0.100004         0.345659  2.905159
# 6       7                  0.150001         0.319993  2.667786
# 7       8                  0.200009         0.295054  2.534374
# 8       9                  0.300002         0.220194  2.077012
# 9      10                  0.400007         0.128482  1.359430
# 10     11                  0.500000         0.034165  0.653661
# 11     12                  0.600004         0.001303  0.100075
# 12     13                  0.699998         0.000874  0.006200
# 13     14                  0.800013         0.000711  0.000886
# 14     15                  0.900007         0.000562  0.002657
# 15     16                  1.000000         0.000090  0.000000
#
#     cumulative_lift  response_rate     score  cumulative_response_rate  \
# 0          3.612155       0.445902  0.451200                  0.445902
# 1          3.607728       0.444809  0.413873                  0.445355
# 2          3.586901       0.437637  0.398375                  0.442784
# 3          3.533440       0.416393  0.387014                  0.436185
# 4          3.492513       0.410929  0.378031                  0.431132
# 5          3.198868       0.358627  0.359834                  0.394884
# 6          3.021854       0.329324  0.332313                  0.373032
# 7          2.899971       0.312855  0.307625                  0.357986
# 8          2.625671       0.256396  0.260827                  0.324125
# 9          2.309102       0.167815  0.173887                  0.285047
# 10         1.978036       0.080691  0.081876                  0.244178
# 11         1.665031       0.012354  0.012355                  0.205539
# 12         1.428070       0.000765  0.001025                  0.176288
# 13         1.249647       0.000109  0.000790                  0.154262
# 14         1.111103       0.000328  0.000638                  0.137160
# 15         1.000000       0.000000  0.000442                  0.123445
#
#     cumulative_score  capture_rate  cumulative_capture_rate        gain  \
# 0           0.451200      0.036135                 0.036135  261.215476
# 1           0.432536      0.036046                 0.072181  260.330144
# 2           0.421157      0.035426                 0.107608  254.520273
# 3           0.412619      0.033744                 0.141352  237.311510
# 4           0.405700      0.033301                 0.174652  232.884850
# 5           0.382770      0.145248                 0.319901  190.515913
# 6           0.365952      0.133381                 0.453281  166.778637
# 7           0.351369      0.126738                 0.580019  153.437428
# 8           0.321190      0.207688                 0.787707  107.701164
# 9           0.284364      0.135949                 0.923656   35.943041
# 10          0.243869      0.065362                 0.989018  -34.633920
# 11          0.205282      0.010008                 0.999026  -89.992467
# 12          0.176104      0.000620                 0.999646  -99.379997
# 13          0.154187      0.000089                 0.999734  -99.911447
# 14          0.137127      0.000266                 1.000000  -99.734284
# 15          0.123459      0.000000                 1.000000 -100.000000
#
#     cumulative_gain  kolmogorov_smirnov
# 0        261.215476            0.029811
# 1        260.772810            0.059522
# 2        258.690150            0.088537
# 3        253.344029            0.115620
# 4        249.251299            0.142198
# 5        219.886817            0.250864
# 6        202.185380            0.345991
# 7        189.997060            0.433527
# 8        162.567094            0.556388
# 9        130.910215            0.597395
# 10        97.803560            0.557886
# 11        66.503082            0.455215
# 12        42.806980            0.341847
# 13        24.964738            0.227848
# 14        11.110301            0.114075
# 15         0.000000            0.000000
# Cross-Validation Metrics Summary:
#                                      mean          sd    cv_1_valid  \
# 0                  accuracy      0.782980    0.011607      0.770423
# 1                       auc      0.857099    0.005759      0.850172
# 2                       err      0.217020    0.011607      0.229577
# 3                 err_count   3969.800000  209.137990   4193.000000
# 4                  f0point5      0.374986    0.015975      0.359241
# 5                        f1      0.461815    0.013598      0.447781
# 6                        f2      0.601304    0.005723      0.594239
# 7            lift_top_group      3.644327    0.390903      3.435338
# 8                   logloss      0.266330    0.003246      0.270012
# 9       max_per_class_error      0.246536    0.010150      0.240054
# 10                      mcc      0.396574    0.012224      0.382986
# 11  mean_per_class_accuracy      0.770320    0.003778      0.765916
# 12     mean_per_class_error      0.229680    0.003778      0.234084
# 13                      mse      0.087194    0.001061      0.087925
# 14            null_deviance  13673.971000  143.051710  13582.816000
# 15                   pr_auc      0.368545    0.018061      0.353389
# 16                precision      0.333252    0.016353      0.317401
# 17                       r2      0.194090    0.010279      0.181938
# 18                   recall      0.753464    0.010150      0.759946
# 19        residual_deviance   9743.635000   84.611010   9862.994000
#
#       cv_2_valid    cv_3_valid    cv_4_valid    cv_5_valid
# 0       0.785275      0.779860      0.777913      0.801432
# 1       0.858423      0.856679      0.854427      0.865794
# 2       0.214725      0.220140      0.222087      0.198568
# 3    3943.000000   4053.000000   4028.000000   3632.000000
# 4       0.372234      0.369947      0.371541      0.401969
# 5       0.459937      0.458372      0.458457      0.484530
# 6       0.601706      0.602346      0.598456      0.609773
# 7       3.421163      3.669512      3.381819      4.313803
# 8       0.262098      0.264568      0.269052      0.265920
# 9       0.242670      0.238116      0.248568      0.263271
# 10      0.397900      0.395303      0.390726      0.415953
# 11      0.773221      0.772124      0.766566      0.773773
# 12      0.226779      0.227876      0.233434      0.226227
# 13      0.085683      0.086655      0.088366      0.087342
# 14  13531.112000  13676.484000  13674.973000  13904.471000
# 15      0.362469      0.363517      0.363399      0.399951
# 16      0.330252      0.327791      0.329851      0.360964
# 17      0.192853      0.192521      0.192651      0.210488
# 18      0.757330      0.761884      0.751432      0.736729
# 19   9625.803000   9741.909000   9759.576000   9727.890000
# See the whole table with table.as_data_frame()

# %%
# predict
test_df = h2o.import_file('data/processed/test.csv')
X_test = test_df.drop('Response')
y_test = test_df['Response']
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
model_uri
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/duong/Desktop/GitFolder/E2E-ML-pipeline-with-data/model_dev/04_autoML_H2O.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/duong/Desktop/GitFolder/E2E-ML-pipeline-with-data/model_dev/04_autoML_H2O.ipynb#ch0000011?line=0'>1</a> model_uri
#
# NameError: name 'model_uri' is not defined

# %%
# Get dataframe of all runs
all_experiments = [exp.experiment_id for exp in client.list_experiments()]
runs = mlflow.search_runs(experiment_ids=all_experiments, run_view_type=ViewType.ALL)

# Identify best model (experiment id and run id) amongst all runs in the experiment
run_id, exp_id = runs.loc[runs['metrics.log_loss'].idxmin()]['run_id'], runs.loc[runs['metrics.log_loss'].idxmin()]['experiment_id']
run_id, exp_id
# Out:
# ('c1ea60db0880418daff84df38bebb190', '2')

# %%
best_model = mlflow.h2o.load_model(f"mlruns/{exp_id}/{run_id}/artifacts/model/")

# %%
preds = best_model.predict(X_test)
# Out:
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%

# %%
y_pred = preds.as_data_frame()['predict']
y_true = y_test.as_data_frame()['Response']

# %%
from sklearn.metrics import confusion_matrix as cm
cm = cm(y_true, y_pred)
print(cm)
# Out:
# [[ 9241 10779]
#  [    5  2842]]

# %%
cm.ravel()
# Out:
# array([ 9241, 10779,     5,  2842])

# %%
mlflow.end_run()

# %%
mlflow.h2o.save_model(best_model, "models")
# Out:
# /home/duong/.cache/pypoetry/virtualenvs/cross-sell-TlDnGNar-py3.8/lib/python3.8/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
